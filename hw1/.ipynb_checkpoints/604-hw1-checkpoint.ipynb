# %% [markdown]
# ![image.png](attachment:97a2d245-cbeb-46a8-933d-f66cb7f16e8b.png)

# %% [markdown]
# ![image.png](attachment:51c8502d-63eb-4128-bf21-d2a17d131749.png)

# %% [markdown]
# ![image.png](attachment:379e8659-c75a-4f22-a50f-157727f6a031.png)

# %% [markdown]
# ![image.png](attachment:50c85edb-6a18-4b8f-bd40-dab967ecfa17.png)

# %% [markdown]
# ![image.png](attachment:3976a452-bfeb-40ce-9f49-51f284c82075.png)
